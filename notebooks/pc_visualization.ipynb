# %%
"""
Load data
"""
import sys
import os
from pathlib import Path

# Project root
root_dir = Path(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Add to Python path for imports
sys.path.insert(0, str(root_dir))

# **CRITICAL**: Change CWD to root so relative paths work
os.chdir(root_dir)
print(f"Root: {root_dir}")
print(f"CWD now: {os.getcwd()}")  # Should match root_dir
# Out:
# Root: /home/mstromie/behavior_prediction
# CWD now: /home/mstromie/behavior_prediction

# %% [markdown]
# ### Load data and visualize point cloud

# %%
from src.data.data_module import load_dataset

raw_data = load_dataset()


cloud = raw_data[0].x
print(cloud)
# Out:
# Fieldnames: ['Species', 'Char']
# Class to index = {'N': 0, 'D': 1, 'C': 2}
# Fieldnames: ['Species', 'Char']
# Class to index = {'N': 0, 'D': 1}
# Fieldnames: ['Species', 'Char']
# Class to index = {'O': 0, 'H': 1, 'C': 2}
# Fieldnames: ['Species', 'Char']
# Class to index = {'O': 0, 'M': 1, 'F': 2}
# Fieldnames: ['Species', 'Char']
# Class to index = {'S': 0, 'G': 1, 'C': 2}
# Fieldnames: ['Species', 'Char']
# Class to index = {'Scandentia': 0, 'Rodentia': 1, 'Primates': 2, 'Perissodactyla': 3, 'Lagomorpha': 4, 'Hyrocoidea': 5, 'Eulipotyphla': 6, 'Diprotodontia': 7, 'Cingulata': 8, 'Chiroptera': 9, 'Carnivora': 10, 'Artiodactyla': 11}
# tensor([[ 85.7768,  25.4286,  44.2500],
#         [ 88.9618,  44.2443,  12.4198],
#         [ 69.8012,  40.2892,  20.4277],
#         [ 49.2901,  32.3588,  43.8550],
#         [ 56.4226,  34.6369,  28.7560],
#         [106.9550,  28.1441,  28.9009],
#         [ 93.2444,  42.9704,  32.1704],
#         [ 82.7306,   8.0155,  26.4093],
# ...

# %%
import plotly.graph_objects as go
import numpy as np

# Your [200,3] tensor
pc = cloud.cpu().numpy()  # Ensure numpy

# Colors & indices as arrays
colors = np.array(['blue'] * 100 + ['red'] * 100)
customdata = np.arange(200)

fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()

# %% [markdown]
# ### Rotate point cloud

# %%
from src.data.transformations import random_rotation

rotated_data = random_rotation(raw_data[0].clone())
# Your [200,3] tensor
pc = rotated_data.x.cpu().numpy()  # Ensure numpy

# Colors & indices as arrays
colors = np.array(['blue'] * 100 + ['red'] * 100)
customdata = np.arange(200)

fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()

# %% [markdown]
# ### Change orientation

# %%
from src.data.transformations import change_orientation

rotated_data = change_orientation(raw_data[0].clone(), target_orientation='LR')
# Your [200,3] tensor
pc = rotated_data.x.cpu().numpy()  # Ensure numpy

# Colors & indices as arrays
colors = np.array(['blue'] * 100 + ['red'] * 100)
customdata = np.arange(200)

fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()

# %% [markdown]
# ### Add jitter

# %%
from src.data.transformations import add_jitter

noisy_data = add_jitter(raw_data[0].clone(), scale=0.5)
# Your [200,3] tensor
pc = noisy_data.x.cpu().numpy()  # Ensure numpy

# Colors & indices as arrays
colors = np.array(['blue'] * 100 + ['red'] * 100)
customdata = np.arange(200)

fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()

# %%
from src.data.transformations import reshape

print(f"Original: {raw_data[0].x}")  # Should be [200,3]

pc = reshape(raw_data[0].clone(), shape=[3, 200]).x.cpu().numpy()  # Ensure numpy


print(f"Reshaped: {pc}")  # Should be [3, 200]
# Out:
# Original: tensor([[ 85.7768,  25.4286,  44.2500],
#         [ 88.9618,  44.2443,  12.4198],
#         [ 69.8012,  40.2892,  20.4277],
#         [ 49.2901,  32.3588,  43.8550],
#         [ 56.4226,  34.6369,  28.7560],
#         [106.9550,  28.1441,  28.9009],
#         [ 93.2444,  42.9704,  32.1704],
#         [ 82.7306,   8.0155,  26.4093],
#         [ 71.8974,  39.3718,  11.1282],
#         [ 62.2035,  46.9381,  41.4159],
#         [ 97.2384,  13.0199,  30.5298],
#         [ 77.1696,  30.0804,  48.5357],
#         [ 69.7109,  48.5781,  16.0469],
#         [ 86.3918,  21.8247,  11.7526],
#         [ 87.2767,  15.4528,  23.3836],
#         [ 84.9852,  42.0667,  40.2815],
#         [114.5164,  37.9590,  27.2213],
#         [ 65.9615,  21.4327,  10.1154],
#         [ 74.6013,  37.8889,  33.3464],
#         [ 93.3205,  37.3782,  40.3590],
#         [ 48.0889,  41.9704,  46.2148],
#         [ 72.1381,  22.5691,  34.3757],
#         [ 83.4161,  44.2993,  20.7591],
# ...

# %% [markdown]
# ### Orientation

# %%
orientation = raw_data[0].pc_orientation
print(f"Original orientation: {orientation}")

for data in raw_data:
    if data.pc_orientation != orientation:
        break

# visualize point cloud with different orientation
print(f"New orientation: {data.pc_orientation}")
# Out:
# Original orientation: RL
# New orientation: LR

# %%
pc = data.x
fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()

# %%
data = change_orientation(data, target_orientation='RL')

pc = data.x
fig = go.Figure(data=[go.Scatter3d(
    x=pc[:,0], y=pc[:,1], z=pc[:,2],
    mode='markers',
    marker=dict(size=4, color=colors, line=dict(width=0.5, color='black'), opacity=0.8),
    name='Left (blue) / Right (red)',
    hovertemplate='<b>Point %{customdata}</b><br>X: %{x:.3f}<br>Y: %{y:.3f}<br>Z: %{z:.3f}<extra></extra>',
    customdata=customdata  # ✅ np.array
)])

fig.update_layout(
    title="Interactive Brain Point Cloud (Fixed)",
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='cube')
)
fig.show()
